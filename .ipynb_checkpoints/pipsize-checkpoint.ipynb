# %%
import os
import pkg_resources

def calc_container(path):
    total_size = 0
    for dirpath, dirnames, filenames in os.walk(path):
        for f in filenames:
            fp = os.path.join(dirpath, f)
            total_size += os.path.getsize(fp)
    return total_size



dists = [d for d in pkg_resources.working_set]

for dist in dists:
    try:
        path = os.path.join(dist.location, dist.project_name)
        size = calc_container(path)
        if size/1000 > 1.0:
            print (f"{dist}: {size/1000} KB")
            print("-"*40)
    except OSError:
        '{} no longer exists'.format(dist.project_name)
# Out:
# certifi 2022.12.7: 282.627 KB
# ----------------------------------------
# regex 2022.10.31: 1349.924 KB
# ----------------------------------------
# pytz 2022.7: 966.533 KB
# ----------------------------------------
# tzdata 2022.7: 502.007 KB
# ----------------------------------------
# cryptography 39.0.0: 6775.834 KB
# ----------------------------------------
# flatbuffers 23.1.4: 172.842 KB
# ----------------------------------------
# packaging 23.0: 221.295 KB
# ----------------------------------------
# attrs 22.2.0: 6.219 KB
# ----------------------------------------
# isoduration 20.11.0: 34.983 KB
# ----------------------------------------
# websockets 10.4: 602.754 KB
# ----------------------------------------
# ipython 8.8.0: 4419.646 KB
# ----------------------------------------
# nbconvert 7.2.8: 472.676 KB
# ----------------------------------------
# ipykernel 6.20.2: 786.853 KB
# ----------------------------------------
# notebook 6.5.2: 2287.182 KB
# ----------------------------------------
# tornado 6.2: 2947.682 KB
# ----------------------------------------
# multidict 6.0.4: 96.95 KB
# ----------------------------------------
# psutil 5.9.4: 1581.805 KB
# ----------------------------------------
# traitlets 5.8.1: 887.494 KB
# ----------------------------------------
# nbformat 5.7.3: 415.739 KB
# ----------------------------------------
# cachetools 5.2.1: 59.155 KB
# ----------------------------------------
# bleach 5.0.1: 1147.469 KB
# ----------------------------------------
# jsonschema 4.17.3: 723.563 KB
# ----------------------------------------
# lxml 4.9.2: 8607.297 KB
# ----------------------------------------
# rsa 4.9: 161.666 KB
# ----------------------------------------
# tzlocal 4.2: 83.687 KB
# ----------------------------------------
# aiohttp 3.8.3: 1571.071 KB
# ----------------------------------------
# h5py 3.7.0: 7110.222 KB
# ----------------------------------------
# anyio 3.6.2: 580.82 KB
# ----------------------------------------
# jupyterlab 3.5.2: 17810.842 KB
# ----------------------------------------
# Markdown 3.4.1: 487.659 KB
# ----------------------------------------
# idna 3.4: 477.854 KB
# ----------------------------------------
# oauthlib 3.2.2: 916.719 KB
# ----------------------------------------
# Jinja2 3.1.2: 912.174 KB
# ----------------------------------------
# requests 2.28.1: 327.286 KB
# ----------------------------------------
# pycparser 2.21: 1026.48 KB
# ----------------------------------------
# fastjsonschema 2.16.2: 137.18 KB
# ----------------------------------------
# Pygments 2.14.0: 6881.655 KB
# ----------------------------------------
# tensorboard 2.11.2: 11860.644 KB
# ----------------------------------------
# Babel 2.11.0: 30225.488 KB
# ----------------------------------------
# keras 2.11.0: 11161.152 KB
# ----------------------------------------
# tensorflow 2.11.0: 1024899.724 KB
# ----------------------------------------
# platformdirs 2.6.2: 77.967 KB
# ----------------------------------------
# frozendict 2.3.4: 83.788 KB
# ----------------------------------------
# soupsieve 2.3.2.post1: 231.632 KB
# ----------------------------------------
# Werkzeug 2.2.2: 1474.589 KB
# ----------------------------------------
# asttokens 2.2.1: 104.889 KB
# ----------------------------------------
# termcolor 2.2.0: 14.438 KB
# ----------------------------------------
# MarkupSafe 2.1.2: 47.692 KB
# ----------------------------------------
# mistune 2.0.4: 126.072 KB
# ----------------------------------------
# tomli 2.0.1: 47.142 KB
# ----------------------------------------
# urllib3 1.26.13: 689.21 KB
# ----------------------------------------
# numpy 1.24.1: 62004.416 KB
# ----------------------------------------
# cffi 1.15.1: 632.174 KB
# ----------------------------------------
# wrapt 1.14.1: 149.584 KB
# ----------------------------------------
# yarl 1.8.2: 162.05 KB
# ----------------------------------------
# Send2Trash 1.8.0: 50.22 KB
# ----------------------------------------
# debugpy 1.6.5: 27651.324 KB
# ----------------------------------------
# astunparse 1.6.3: 61.572 KB
# ----------------------------------------
# pandas 1.5.2: 51265.643 KB
# ----------------------------------------
# fqdn 1.5.1: 10.414 KB
# ----------------------------------------
# frozenlist 1.3.3: 62.611 KB
# ----------------------------------------
# aiosignal 1.3.1: 2.593 KB
# ----------------------------------------
# sniffio 1.3.0: 11.374 KB
# ----------------------------------------
# arrow 1.2.3: 460.342 KB
# ----------------------------------------
# tinycss2 1.2.1: 144.655 KB
# ----------------------------------------
# executing 1.2.0: 115.797 KB
# ----------------------------------------
# dateparser 1.1.5: 1897.73 KB
# ----------------------------------------
# html5lib 1.1: 938.134 KB
# ----------------------------------------
# wheel 0.38.4: 170.122 KB
# ----------------------------------------
# pyrsistent 0.19.3: 307.655 KB
# ----------------------------------------
# jedi 0.18.2: 4985.979 KB
# ----------------------------------------
# terminado 0.17.1: 65.763 KB
# ----------------------------------------
# ta 0.10.2: 357.599 KB
# ----------------------------------------
# json5 0.9.11: 128.38 KB
# ----------------------------------------
# parso 0.8.3: 530.882 KB
# ----------------------------------------
# nbclient 0.7.2: 313.756 KB
# ----------------------------------------
# defusedxml 0.7.1: 62.718 KB
# ----------------------------------------
# webencodings 0.5.1: 56.591 KB
# ----------------------------------------
# nbclassic 0.4.8: 36047.292 KB
# ----------------------------------------
# pyasn1 0.4.8: 621.42 KB
# ----------------------------------------
# colorama 0.4.6: 110.685 KB
# ----------------------------------------
# gast 0.4.0: 74.015 KB
# ----------------------------------------
# voila 0.4.0: 234.933 KB
# ----------------------------------------
# wcwidth 0.2.6: 482.315 KB
# ----------------------------------------
# yfinance 0.2.4: 245.154 KB
# ----------------------------------------
# backcall 0.2.0: 54.707 KB
# ----------------------------------------
# comm 0.1.2: 18.468 KB
# ----------------------------------------
# multitasking 0.0.11: 7.708 KB
# ----------------------------------------
# setuptools 65.5.0: 7993.847 KB
# ----------------------------------------
# pip 22.3.1: 20463.721 KB
# ----------------------------------------

# %%
pip uninstall keras
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
pip list
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# Package                      Version
# ---------------------------- -----------
# absl-py                      1.4.0
# aiohttp                      3.8.3
# aiosignal                    1.3.1
# anyio                        3.6.2
# appdirs                      1.4.4
# argon2-cffi                  21.3.0
# argon2-cffi-bindings         21.2.0
# arrow                        1.2.3
# asttokens                    2.2.1
# astunparse                   1.6.3
# async-timeout                4.0.2
# attrs                        22.2.0
# autopep8                     2.0.1
# Babel                        2.11.0
# backcall                     0.2.0
# beautifulsoup4               4.11.1
# bleach                       5.0.1
# cachetools                   5.2.1
# certifi                      2022.12.7
# cffi                         1.15.1
# charset-normalizer           2.1.1
# colorama                     0.4.6
# comm                         0.1.2
# cryptography                 39.0.0
# dateparser                   1.1.5
# debugpy                      1.6.5
# decorator                    5.1.1
# defusedxml                   0.7.1
# entrypoints                  0.4
# executing                    1.2.0
# fastjsonschema               2.16.2
# flatbuffers                  23.1.4
# fqdn                         1.5.1
# frozendict                   2.3.4
# frozenlist                   1.3.3
# gast                         0.4.0
# google-auth                  2.16.0
# google-auth-oauthlib         0.4.6
# google-pasta                 0.2.0
# grpcio                       1.51.1
# h5py                         3.7.0
# html5lib                     1.1
# idna                         3.4
# ipykernel                    6.20.2
# ipython                      8.8.0
# ipython-genutils             0.2.0
# isoduration                  20.11.0
# jedi                         0.18.2
# Jinja2                       3.1.2
# json5                        0.9.11
# jsonpointer                  2.3
# jsonschema                   4.17.3
# jupyter_client               7.4.1
# jupyter_core                 5.1.3
# jupyter-events               0.6.3
# jupyter-server               1.23.5
# jupyter_server_terminals     0.4.4
# jupyterlab                   3.5.2
# jupyterlab-pygments          0.2.2
# jupyterlab_server            2.19.0
# keras                        2.11.0
# libclang                     15.0.6.1
# lxml                         4.9.2
# Markdown                     3.4.1
# MarkupSafe                   2.1.2
# matplotlib-inline            0.1.6
# mistune                      2.0.4
# multidict                    6.0.4
# multitasking                 0.0.11
# nbclassic                    0.4.8
# nbclient                     0.7.2
# nbconvert                    7.2.8
# nbformat                     5.7.3
# nest-asyncio                 1.5.6
# notebook                     6.5.2
# notebook_shim                0.2.2
# numpy                        1.24.1
# oauthlib                     3.2.2
# opt-einsum                   3.3.0
# packaging                    23.0
# pandas                       1.5.2
# pandocfilters                1.5.0
# parso                        0.8.3
# pickleshare                  0.7.5
# platformdirs                 2.6.2
# prometheus-client            0.15.0
# prompt-toolkit               3.0.36
# protobuf                     3.19.6
# psutil                       5.9.4
# pure-eval                    0.2.2
# pyasn1                       0.4.8
# pyasn1-modules               0.2.8
# pycodestyle                  2.10.0
# pycparser                    2.21
# Pygments                     2.14.0
# pyrsistent                   0.19.3
# python-binance               1.0.16
# python-dateutil              2.8.2
# python-json-logger           2.0.4
# pytz                         2022.7
# pytz-deprecation-shim        0.1.0.post0
# pywin32                      305
# pywinpty                     2.0.10
# PyYAML                       6.0
# pyzmq                        25.0.0
# regex                        2022.10.31
# requests                     2.28.1
# requests-oauthlib            1.3.1
# rfc3339-validator            0.1.4
# rfc3986-validator            0.1.1
# rsa                          4.9
# Send2Trash                   1.8.0
# six                          1.16.0
# sniffio                      1.3.0
# soupsieve                    2.3.2.post1
# stack-data                   0.6.2
# ta                           0.10.2
# tensorboard                  2.11.2
# tensorboard-data-server      0.6.1
# tensorboard-plugin-wit       1.8.1
# tensorflow                   2.11.0
# tensorflow-estimator         2.11.0
# tensorflow-intel             2.11.0
# tensorflow-io-gcs-filesystem 0.29.0
# termcolor                    2.2.0
# terminado                    0.17.1
# tinycss2                     1.2.1
# tomli                        2.0.1
# tornado                      6.2
# traitlets                    5.8.1
# typing_extensions            4.4.0
# tzdata                       2022.7
# tzlocal                      4.2
# ujson                        5.6.0
# uri-template                 1.2.0
# urllib3                      1.26.13
# voila                        0.4.0
# wcwidth                      0.2.6
# webcolors                    1.12
# webencodings                 0.5.1
# websocket-client             1.4.2
# websockets                   10.4
# Werkzeug                     2.2.2
# wheel                        0.38.4
# wrapt                        1.14.1
# yarl                         1.8.2
# yfinance                     0.2.4
